# %%
import pandas as pd
import os

project_path = os.path.dirname(os.path.dirname(os.getcwd()))
data_path = os.path.join(project_path, "assets/megaGymDataset.csv")
data_path
# Out:
# '/home/zachos/projects/RAGlepedia/assets/megaGymDataset.csv'

# %%
df = pd.read_csv(data_path)
df.dropna(inplace=True)
df.drop(['Unnamed: 0','Rating', 'RatingDesc'], axis=1, inplace=True)
# df.reset_index(drop=True, inplace=True)
df[:500]
# Out:
#                                   Title  \
# 8                      Barbell roll-out
# 9         Barbell Ab Rollout - On Knees
# 10             Decline bar press sit-up
# 11               Bench barbell roll-out
# 13                     Seated bar twist
# ...                                 ...
# 2887            Feet-elevated bench dip
# 2888           Bodyweight triceps press
# 2894  Straight-arm plank with kick-back
# 2911        Decline EZ-bar skullcrusher
# 2912                EZ-Bar Skullcrusher
#
#                                                    Desc      Type    BodyPart  \
# 8     The barbell roll-out is an abdominal exercise ...  Strength  Abdominals
# 9     The barbell roll-out is an abdominal exercise ...  Strength  Abdominals
# 10    The decline bar press sit-up is a weighted cor...  Strength  Abdominals
# 11    The bench barbell roll-out is a challenging ex...  Strength  Abdominals
# 13    The seated bar twist is a core exercise meant ...  Strength  Abdominals
# ...

# %%
df.iloc[0]['Title']
# Out:
# 'Barbell roll-out'

# %%
# convert df to text format
with open(os.path.join(project_path, "assets/megaGymDataset.txt"), "w+") as file:
    for i in range(len(df)):
        title = df.iloc[i]['Title']
        desc = df.iloc[i]['Desc']
        type = df.iloc[i]['Type']
        bodypart = df.iloc[i]['BodyPart']
        equip = df.iloc[i]['Equipment']
        level = df.iloc[i]['Level']
        string = f"Exercise name: {title}\nExercise Description: {desc}\nExercise Type: {type}\nExercise BodyPart: {bodypart}\nExercise Equipment: {equip}\nExercise Level: {level}\n----------+\n"
        file.write(string)

# %%
with open(os.path.join(project_path, "assets/megaGymDataset.txt"), "r+") as f:
    lines = f.readlines()
    

text = "".join(lines)
data = text.split("\n----------+\n")

# %%
title
# Out:
# 'EZ-bar skullcrusher-'

# %%
from langchain_community.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter, CharacterTextSplitter

loader = TextLoader(os.path.join(project_path, "assets/megaGymDataset.txt"))
text_documents = loader.load()
text_splitter = CharacterTextSplitter(chunk_size = 400, chunk_overlap=20, separator='\n----------+\n', strip_whitespace=False)
text_splitter.split_documents(text_documents)[:5]
# Out:
# Created a chunk of size 548, which is longer than the specified 400
# Created a chunk of size 561, which is longer than the specified 400
# Created a chunk of size 519, which is longer than the specified 400
# Created a chunk of size 455, which is longer than the specified 400
# Created a chunk of size 506, which is longer than the specified 400
# Created a chunk of size 498, which is longer than the specified 400
# Created a chunk of size 435, which is longer than the specified 400
# Created a chunk of size 560, which is longer than the specified 400
# Created a chunk of size 409, which is longer than the specified 400
# Created a chunk of size 658, which is longer than the specified 400
# Created a chunk of size 566, which is longer than the specified 400
# Created a chunk of size 412, which is longer than the specified 400
# Created a chunk of size 435, which is longer than the specified 400
# Created a chunk of size 489, which is longer than the specified 400
# ...

# %%
# Out:
# UUID('c0ab680e-b889-43a5-b83b-f34322bd5750')
